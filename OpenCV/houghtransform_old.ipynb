# %% [markdown]
# <a href="https://colab.research.google.com/github/WarpHero/AI_Training_Practice/blob/main/houghtransform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hough Transform
# ## 1.

# %%
# !pip install opencv-python-headless
# !pip install transformers

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
# 이미지 로드
img = cv2.imread('lineSample.jpg', cv2.IMREAD_GRAYSCALE)
# img = cv2.imread('path_to_your_image.jpg')
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# %%
edges = cv2.Canny(img, 50, 150, apertureSize=3)

# %%
lines = cv2.HoughLinesP(edges, 1, np.pi / 180, threshold=100, minLineLength=100, maxLineGap=10)
 # 예를 들어, 200에서 100으로 변경

# %%
# 검출된 선 그리기
if lines is not None:
    for line in lines:
        x1, y1, x2, y2 = line[0]  # line[0]에서 각 점의 좌표를 가져옵니다.
        cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
else:
    print("No lines found.")

# %%
cv2_imshow(img)  # Colab에서 사용
# Out:
# <PIL.Image.Image image mode=L size=1400x845>
